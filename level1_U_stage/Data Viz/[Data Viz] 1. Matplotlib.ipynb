# %%
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import numpy as np 
import matplotlib as mpl

print(f'numpy version : {np.__version__}') # version check
print(f'matplotlib version : {mpl.__version__}') # version check
# pylab은 pyplot으로 대체됨
import matplotlib.pyplot as plt
# Out:
# numpy version : 1.21.2
# matplotlib version : 3.5.0

# %% [markdown]
# ## 기본 Plot
#
# ### FIgure와 Axes
# Figure라는 큰틀에 Ax라는 서브 플롯을 추가해서 만들게 된다.

# %%
fig = plt.figure()
plt.show() # 그림을 그려달라.

# %% [markdown]
# Figure에 서브플롯을 최소 1개 이상 추가해야 한다.(천개 만개도 가능..)

# %%
fig = plt.figure()
# fig라는 객체에 subplot을 추가한다.
ax = fig.add_subplot()
plt.show()

# %% [markdown]
# 그래프의 사이즈는 figure의 사이즈, 서브플롯 ax의 사이즈로 조정한다.
#
# 가로, 세로(inch 단위)를 튜플 형태로 `figsize`에 전달하여 조절한다.

# %%
fig = plt.figure(figsize=(12, 7))
# fig의 색을 변경하는 코드, fig라는 팔레트에 ax라는 subplot을 그린 형태
#fig.set_facecolor('black')
ax = fig.add_subplot()
plt.show()

# %% [markdown]
# 세로로 쪼개서 사용

# %%
fig = plt.figure()
# 가로 1 세로 2로 나눴을때 첫번째에 추가
# ax = fig.add_subplot(1,2,1)
ax = fig.add_subplot(121)
ax = fig.add_subplot(122)
plt.show()

# %% [markdown]
# 가로로 쪼개서 사용

# %%
fig = plt.figure()
# 가로 1 세로 2로 나눴을때 첫번째에 추가
# ax = fig.add_subplot(1,2,1)
ax = fig.add_subplot(211)
ax = fig.add_subplot(212)
plt.show()

# %%
fig = plt.figure()
# 가로 1 세로 2로 나눴을때 첫번째에 추가
# ax = fig.add_subplot(1,2,1)
ax = fig.add_subplot(221)
ax = fig.add_subplot(224)
plt.show()

# %% [markdown]
# ### 그래프 그리기
#
# `plot` 을 사용하여 선그래프를 그릴 수 있다.

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = np.array([1, 2, 3])

plt.plot(x)
plt.show()

# %% [markdown]
# plt를 사용하여 그래프를 순차적으로 그릴 수 있다.

# %% [markdown]
# ### 서브플롯 객체 ax에 직접 그리기
# `ax` 객체에 직접 그리면 pythonic하게 그릴 수 있다.
#
# * pyplot API : 순차적 방법
# * 객체지향 API : 그래프에서 각 객체에 대해 직접 수정

# %%
# pyplot API
fig = plt.figure()

x1 = [1,2,3]
x2 = [3,2,1]


ax = fig.add_subplot(211)
plt.plot(x1)
ax2 = fig.add_subplot(212)
plt.plot(x2)

plt.show()

# %%
# 객체지향 API
fig = plt.figure()
x1 = [1,2,3]
x2 = [3,2,1]

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
ax1.plot(x1)
ax2.plot(x2)
plt.show()

# %% [markdown]
# 한 서브플롯에 여러 그래프 그리기

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# 3개 plot 동시에 그리기
ax.plot([1, 1, 1])
ax.plot([1, 2, 3])
ax.plot([3, 3, 3])

plt.show()

# %% [markdown]
# 같은 종류의 그래프는 자동으로 색상이 구분된다.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# 서로 다른 종류의 그래프를 그릴시 색상 구분이 안됨
ax.plot([1,2,3],[1,2,3])
ax.bar([1,2,3],[1,2,3])

plt.show()

# %% [markdown]
# ### 색상 지정하기
# `color` 파라미터를 통해 색상을 변경할 수 있다.
#
# * 색에 대한 조합은 rgb hex을 참조

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# 3개 plot 동시에 그리기
ax.plot([1, 1, 1], color='r')# 한 글자로 지정
ax.plot([1, 2, 3], color='forestgreen') # color name
ax.plot([3, 3, 3], color='#000000') # hex code, 가장 추천

plt.show()

# %% [markdown]
# ### 텍스트 사용하기
#
# 정보를 추가하기 위해 텍스트를 사용하자.
#
# * `label`
# * `legend`(범례)
# * `set_title`(제목)
#     * `fig.suptitle` : fig의 제목

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 1, 1], label='1')
ax.plot([1, 2, 3], label='2')
ax.plot([3, 3, 3], label='3')
ax.legend() # 범례를 쓰지 않으면 그래프에 나타나지 않는다
ax.set_title("Basic Plot") # 제목을 추가
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# subplot 각각에 타이틀 지정 가능
ax1.set_title('ax1')
ax2.set_title('ax2')

fig.suptitle('fig') # sup(super)title
plt.show()

# %% [markdown]
# 📢
#
# ax에서 특정 데이터를 변경하는 경우 : `.set_{}()` 형태의 메서드가 많다.
#
# `set`으로 세팅하는 정보들은 정보를 받아올때는 `.get_{}()` 형태의 메서드를 사용한다.
#
# * `ax.get_title()`

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 1, 1], label='1')
ax.plot([1, 2, 3], label='2')
ax.plot([3, 3, 3], label='3')
ax.legend() 
ax.set_title("Basic Plot") 

print(ax.get_title()) # ax의 title을 가져옴
plt.show()
# Out:
# Basic Plot

# %% [markdown]
# #### 축
# 축은 `ticks`와 `ticklabels`로 구분됨

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 1, 1], label='1')
ax.plot([1, 2, 3], label='2')
ax.plot([3, 3, 3], label='3')
ax.legend() 

ax.set_title("Basic Plot") 
ax.set_xticks([0, 1, 2])

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 1, 1], label='1')
ax.plot([1, 2, 3], label='2')
ax.plot([3, 3, 3], label='3')
ax.legend() 
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['zero', 'one', 'two']) # 라벨을 붙여줌

plt.show()

# %% [markdown]
# 그래프에 텍스트를 추가하는 방법
# * `ax.text(x,y,s=문자열)` : 원하는 위치에 적어줌
# * `ax.annotate(text,xy=(x,y))` : 원하는 위치에 텍스트를 지정함
#     * `xytext=(x,y), arrowprop=` : 화살표까지 추가 가능

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 1, 1], label='1')
ax.plot([1, 2, 3], label='2')
ax.plot([3, 3, 3], label='3')
ax.legend() 
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['zero', 'one', 'two']) # 라벨을 붙여줌

ax.text(x=1, y=2, s="Text") 
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 1, 1], label='1')
ax.plot([1, 2, 3], label='2')
ax.plot([3, 3, 3], label='3')
ax.legend() 
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['zero', 'one', 'two']) # 라벨을 붙여줌

ax.annotate(text="Annotate", xy=(1,2),
           xytext=(1.2, 2.2),
           arrowprops=dict(facecolor='black')) 
plt.show()
